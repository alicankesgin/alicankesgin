# %% [markdown]
# # 📊 Data Visualization - MODÜL 2: Seaborn ile Gelişmiş GörselleştirmeBu modülde Seaborn kütüphanesi ile kategori bazlı ve istatistiksel görselleştirmeler yapılacaktır.

# %% [markdown]
# ## 🔹 Giriş: Seaborn ve Örnek Veri

# %%
import seaborn as snsimport pandas as pdimport matplotlib.pyplot as pltdf = sns.load_dataset("tips")  # Bahşiş veri setidf.head()

# %% [markdown]
# ## 🔹 Barplot: Ortalama Hesap

# %%
sns.barplot(x="day", y="total_bill", data=df)plt.title("Günlere Göre Ortalama Fatura")plt.show()

# %% [markdown]
# ## 🔹 Boxplot: Dağılımı Gösterme

# %%
sns.boxplot(x="day", y="total_bill", data=df)plt.title("Günlere Göre Fatura Dağılımı")plt.show()

# %% [markdown]
# ## 🔹 Violinplot: Yoğunluk + Boxplot

# %%
sns.violinplot(x="day", y="total_bill", data=df, hue="sex", split=True)plt.title("Cinsiyete Göre Fatura Dağılımı")plt.show()

# %% [markdown]
# ## 🔹 Scatterplot: Dağılım Grafiği

# %%
sns.scatterplot(x="total_bill", y="tip", data=df, hue="sex", style="smoker")plt.title("Fatura ve Bahşiş Arasındaki İlişki")plt.show()

# %% [markdown]
# ## 🔹 Heatmap: Korelasyon Matrisi

# %%
corr = df.corr(numeric_only=True)sns.heatmap(corr, annot=True, cmap="coolwarm")plt.title("Korelasyon Matrisi")plt.show()
