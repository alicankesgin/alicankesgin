# %% [markdown]
# # 📘 MODÜL 1: Python'a GirişBu modülde Python programlama diline giriş yapıyoruz. Python’un temelleri, neden tercih edildiği, nasıl kurulduğu ve ilk kodlarımız işlenecektir.

# %% [markdown]
# ## 🔹 Python Nedir?Python, öğrenmesi kolay, okunabilirliği yüksek ve çok yönlü bir programlama dilidir. Web geliştirme, veri bilimi, yapay zeka, otomasyon ve daha birçok alanda yaygın olarak kullanılır.

# %% [markdown]
# ## 🔹 Neden Python?- Temiz ve okunabilir sözdizimi- Geniş topluluk ve kütüphane desteği- Veri bilimi ve yapay zeka alanında lider dil- Hem küçük projeler hem büyük sistemler için uygundur

# %% [markdown]
# ## 🔹 İlk Python Kodumuz

# %%
# Merhaba Dünya! mesajı yazdırılırprint("Merhaba Python!")

# %% [markdown]
# ## 🔹 Yorum SatırlarıYorum satırları kodun çalışmasını etkilemez ve açıklama eklemek için kullanılır.

# %%
# Bu bir yorum satırıdırprint("Bu satır çalışır")  # Bu yorum satırı, bu satıra açıklama ekler

# %% [markdown]
# ## 🔹 Python Nasıl Çalışır?Python yorumlayıcı (interpreter) ile çalışır. Satır satır okunur ve çalıştırılır. Bu, hata ayıklamayı kolaylaştırır.

# %% [markdown]
# ## 🔹 Kullanıcıdan Veri Alma ve Ekrana Yazdırma

# %%
# input() ile kullanıcıdan veri alınırisim = input("Adınızı girin: ")print("Hoş geldin, " + isim + "!")

# %% [markdown]
# ## 🔹 Hata ÖrnekleriKodlamada hatalar kaçınılmazdır. Python yorumlayıcısı hatayı açık şekilde bildirir.

# %%
# print komutu yanlış yazılırsa ne olur?# aşağıdaki satırı çalıştırdığınızda hata alırsınız# prin("Bu bir hata örneğidir")
