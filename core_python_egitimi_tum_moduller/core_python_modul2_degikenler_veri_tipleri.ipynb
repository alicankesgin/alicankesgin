# %% [markdown]
# # 📘 MODÜL 2: Değişkenler ve Veri TipleriBu modülde Python'da değişken tanımlamayı, veri türlerini ve veri tipi dönüşümlerini öğreneceğiz.

# %% [markdown]
# ## 🔹 Değişken Nedir?Değişkenler, verileri saklamak için isimlendirilmiş alanlardır.

# %%
# Değişken tanımlamasayi = 10isim = "Ahmet"print(sayi)print(isim)

# %% [markdown]
# ## 🔹 Temel Veri TürleriPython'da yaygın kullanılan temel veri türleri:

# %%
# Sayısal veri tipleritam_sayi = 10              # intondalikli_sayi = 3.14      # floatkarma_sayi = 2 + 3j        # complex# Metinsel veri tipimetin = "Python öğreniyorum"  # str# Mantıksal veri tipidogru_mu = True               # boolprint(type(tam_sayi))print(type(ondalikli_sayi))print(type(karma_sayi))print(type(metin))print(type(dogru_mu))

# %% [markdown]
# ## 🔹 Veri Tipi Dönüşümleri

# %%
sayi_str = "123"sayi_int = int(sayi_str)print(sayi_int + 1)# float → int dönüşümondalik = 5.89print(int(ondalik))  # Ondalık kısmı atar# str → float dönüşümstr_sayi = "45.67"print(float(str_sayi))

# %% [markdown]
# ## 🔹 Değişken İsimlendirme Kuralları- Harf, rakam ve alt çizgi kullanılabilir.- Rakamla başlayamaz.- Anahtar kelimeler (if, for, return vb.) kullanılamaz.

# %% [markdown]
# ## 🔹 Uygulama: Kullanıcıdan veri al ve türünü göster

# %%
kullanici_yasi = input("Yaşınızı girin: ")print("Girdiğiniz yaş:", kullanici_yasi)print("Tipi:", type(kullanici_yasi))# Tip dönüşümükullanici_yasi = int(kullanici_yasi)print("1 yıl sonra yaşınız:", kullanici_yasi + 1)
