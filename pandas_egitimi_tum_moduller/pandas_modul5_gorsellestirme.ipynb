# %% [markdown]
# # 📘 Pandas Eğitimi - MODÜL 5: GörselleştirmeBu modülde Pandas ile veri görselleştirme araçları (`plot`, `hist`, `boxplot`) gösterilecektir.

# %% [markdown]
# ## 🔹 Gerekli Kütüphaneler ve Örnek Veri

# %%
import pandas as pdimport matplotlib.pyplot as plt# Örnek veriveri = {    "notlar": [70, 85, 90, 95, 100, 65, 80, 75, 60, 88]}df = pd.DataFrame(veri)df

# %% [markdown]
# ## 🔹 Line Plot (Çizgi Grafiği)

# %%
df.plot(y="notlar", kind="line", title="Notların Çizgi Grafiği")plt.xlabel("Öğrenci No")plt.ylabel("Not")plt.grid()plt.show()

# %% [markdown]
# ## 🔹 Histogram (Dağılım Grafiği)

# %%
df["notlar"].plot(kind="hist", bins=5, title="Not Dağılımı", edgecolor="black")plt.xlabel("Not Aralıkları")plt.grid()plt.show()

# %% [markdown]
# ## 🔹 Boxplot (Kutu Grafiği)

# %%
df.boxplot(column="notlar")plt.title("Notların Kutu Grafiği")plt.ylabel("Not")plt.grid()plt.show()
